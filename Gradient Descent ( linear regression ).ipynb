# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.formula.api as sm
from matplotlib import cm
import seaborn as sns

# %%
data= "C:\\Users\\om sai\\Downloads\\students.csv"
students_df= pd.read_csv(data)

# %%
students_df.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
math= students_df["Math"]
read= students_df["Reading"]
write=students_df["Writing"]

fig = plt.figure()
ax =Axes3D(fig)
ax.scatter(math,read,write,color='b')
plt.show()

# %%
def gradient_descent(x,y,theta,iterations,alpha):
    costs=[]
    thetas=[theta]
    for i in range (iterations):
        prediction = np.dot(x,theta)
        error=prediction-y
        cost=1/(2*m)*np.dot(error.T,error)
        costs.append(cost)
        gradient =(1/m) * np.dot(x.T,error)
        theta= theta -(alpha * gradient)
        thetas.append(theta)
    return thetas,costs

def rmse(y,y_pred):
    rmse=np.sqrt(sum((y-y_pred)**2)/len(y))
    return rmse
def r2_score(y,y_pred):
    mean_y=np.mean(y)
    ss_tot = sum((y-mean_y)**2)
    ss_res = sum((y-y_pred)**2)
    r2=1-(ss_res/ss_tot)
    return r2

# %%
X=students_df[['Math','Reading']]
y=students_df['Writing']
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.3)

# %%
alpha = 0.00001
iterations = 10000
m=y.size
np.random.seed(123)
theta=np.random.rand(3)

# %%
theta
# Out:
# array([0.69646919, 0.28613933, 0.22685145])

# %%
ones = np.ones(X_train.shape[0])
X_train=np.c_[ones,X_train]
X_test = np.c_[np.ones(X_test.shape[0]),X_test]

# %%
thetas,costs= gradient_descent(X_train,y_train,theta,iterations,alpha)
out_theta = thetas[-1]
print("final value of theta are :",out_theta)
# Out:
# final value of theta are : [0.69375329 0.10956913 0.86674201]

# %%
y_pred =np.dot(X_test,thetas[-1])
print(rmse(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 4.633637749808794
# 0.9108746255618364
